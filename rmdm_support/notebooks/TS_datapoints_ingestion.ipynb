# %%
import pandas as pd
import pickle
import numpy as np
import re
from cognite.client import CogniteClient
from cognite.client.exceptions import CogniteAPIError
import types
import sys
import warnings
warnings.filterwarnings("ignore")

def is_str(x):
    return isinstance(x, (str, np.str_))   # covers Python and NumPy strings

def is_series(x):
    return isinstance(x, pd.Series)

# %%
# make the client object
# this can be done in many different ways, pick the one you feel more comfortable with...

client = CogniteClient()

# %% [markdown]
# #### Retrieve Production Data

# %%
# ---- Compatibility shim (no __new__ override!) ----
class DummyIndex(pd.Index):
    pass

numeric_module = types.ModuleType("pandas.core.indexes.numeric")
numeric_module.Int64Index  = DummyIndex
numeric_module.UInt64Index = DummyIndex
numeric_module.Float64Index = DummyIndex
numeric_module.RangeIndex  = pd.RangeIndex  # this still exists

sys.modules['pandas.core.indexes.numeric'] = numeric_module

# ---- Load pickle ----
with open("GOM_production.pickle", "rb") as f:
    production_data = pickle.load(f)

# %%
df_meters = client.raw.rows.retrieve_dataframe("bsee", "meters_headers", limit=-1)
df_meters = df_meters.reset_index().rename(columns={"index": "external_id"})

df_well = client.raw.rows.retrieve_dataframe("bsee", "well_headers", limit=-1)
df_well = df_well.reset_index().rename(columns={"index": "external_id"})

# normalize dtypes
df_well   = df_well.copy()
df_meters = df_meters.copy()
col = 'PLATFORM_ID'  # or 'platfid'
mask = df_well[col].notna()
df_well.loc[mask, col] = (
    'PLTF-' + df_well.loc[mask, col].astype(str).str.replace(r'^PLTF-', '', regex=True)
)
df_well['API_WELL_NUMBER'] = df_well['API_WELL_NUMBER'].astype(str).str.strip()
df_meters['PLATFORM_ID'] = df_meters['PLATFORM_ID'].astype(str).str.strip()
df_meters['METER_ID'] = (
    'EQ_MET-' 
    + df_meters['FMP_NUMBER'].astype(str).str.strip()
    + '-'
    + df_meters['METER_SERIAL_NUM'].astype(str).str.strip()
)

# all wells per platform (NO per-platform drop!)
well_on_platform = (
    df_well[['PLATFORM_ID','API_WELL_NUMBER','WELL_NAME']]
    .dropna(subset=['PLATFORM_ID','API_WELL_NUMBER'])
    .drop_duplicates()       # keeps ALL wells on each platform
)

# meters per platform (dedup exact repeats)
meters_on_platform = (
    df_meters[['PLATFORM_ID','METER_ID','FMP_MEAS_TYP_DESC']]
    .dropna(subset=['PLATFORM_ID','METER_ID'])
    .drop_duplicates()
)

# attach every (platform, meter) to EVERY well on that platform
df_meters_w_parents = (
    meters_on_platform
    .merge(well_on_platform, on='PLATFORM_ID', how='inner')
)

# optional: clean up / sanity
df_meters_w_parents.drop(columns=['external_id'], errors='ignore', inplace=True)

print("meters_on_platform:", len(meters_on_platform))
print("well_on_platform:", len(well_on_platform))
print("rows after attach (should be >= meters_on_platform):", len(df_meters_w_parents))

df_meters_w_parents.head()
# Out:
# meters_on_platform: 977
# well_on_platform: 2831
# rows after attach (should be >= meters_on_platform): 24491

# %%
all_prod = {k[:-2]: v for k, v in production_data.items()}

# %%
for k, rec in all_prod.items():
    df = rec['Production Data'].copy().sort_values('Production Date').reset_index(drop=True)

    # ensure numeric & safe denom
    cols = ['Oil (bbls)', 'Gas (bbls)', 'Water (bbls)', 'Days of Production']
    df[cols] = df[cols].apply(pd.to_numeric, errors='coerce')
    days = df['Days of Production'].replace(0, np.nan)

    # per-day rates
    df['OIL_BBL_PER_DAY'] = (df['Oil (bbls)']   / days).replace([np.inf, -np.inf], np.nan).fillna(0)
    df['GAS_MCF_PER_DAY'] = (df['Gas (bbls)']   / days).replace([np.inf, -np.inf], np.nan).fillna(0)  # adjust col name if gas is stored as Mcf column
    df['WATER_BBL_PER_DAY'] = (df['Water (bbls)'] / days).replace([np.inf, -np.inf], np.nan).fillna(0)
    df['CUMULATIVE_BOE_PER_DAY'] = ((df['Oil (bbls)'] + df['Gas (bbls)']/5.8) / days)\
                                .replace([np.inf, -np.inf], np.nan).fillna(0)

    # keep full DF
    rec['Production Data'] = df

    # expose TS as (date, value) lists
    rec['OIL_BBL_PER_DAY'] = list(df[['Production Date', 'OIL_BBL_PER_DAY']].itertuples(index=False, name=None))
    rec['GAS_MCF_PER_DAY'] = list(df[['Production Date', 'GAS_MCF_PER_DAY']].itertuples(index=False, name=None))
    rec['WATER_BBL_PER_DAY'] = list(df[['Production Date', 'WATER_BBL_PER_DAY']].itertuples(index=False, name=None))
    rec['CUMULATIVE_BOE_PER_DAY_TS'] = list(df[['Production Date', 'CUMULATIVE_BOE_PER_DAY']].itertuples(index=False, name=None))

# %%
# -----------------------------
# 0) Normalize & classify meters
# -----------------------------
m = df_meters_w_parents.copy()
m['API_WELL_NUMBER'] = m['API_WELL_NUMBER'].astype(str)
m['desc_norm'] = m['FMP_MEAS_TYP_DESC'].astype(str).str.lower()

# classify to the three buckets we care about
m['class'] = np.select(
    [
        m['desc_norm'].str.contains(r'\bgas\s*royalty\b', regex=True),
        m['desc_norm'].str.contains(r'liquid\s*allocation|alloc\b', regex=True),
        m['desc_norm'].str.contains(r'liquid\s*royalty\b', regex=True),
    ],
    ['gas', 'liquid_alloc', 'liquid_royalty'],
    default='other'
)

# keep only relevant meter classes
m = m[m['class'].isin(['gas','liquid_alloc','liquid_royalty'])].copy()

# -----------------------------------
# 1) Build per-API meter assignments
# -----------------------------------
def pick_meters(g: pd.DataFrame):
    # unique, deterministic ordering
    lr = sorted(set(g.loc[g['class']=='liquid_royalty','METER_ID'].astype(str)))
    la = sorted(set(g.loc[g['class']=='liquid_alloc','METER_ID'].astype(str)))
    gas = sorted(set(g.loc[g['class']=='gas','METER_ID'].astype(str)))

    issues = []

    # GAS: exactly one gas royalty meter
    gas_meter = gas[0] if gas else None
    if not gas: issues.append('missing gas meter')
    if len(gas) > 1: issues.append('multiple gas meters; picking first')

    # OIL: MUST be a liquid royalty meter
    oil_meter = lr[0] if lr else None
    if not lr: issues.append('missing liquid royalty for oil')

    # WATER: prefer liquid allocation; else use SECOND liquid royalty
    water_meter = la[0] if la else (lr[1] if len(lr) >= 2 else None)
    if la and len(la) > 1:
        issues.append('multiple liquid allocation meters; picking first')
    if not la and len(lr) < 2:
        issues.append('need two liquid meters (2×LR or 1×LR + 1×LA)')

    return {'oil': oil_meter, 'gas': gas_meter, 'water': water_meter}, issues

assignments = {}
violations = {}

for api, g in m.groupby('API_WELL_NUMBER'):
    chosen, issues = pick_meters(g)
    assignments[api] = chosen
    if issues:
        violations[api] = issues

# -----------------------------
# 2) Well/platform metadata
# -----------------------------
# Prefer df_well for scalar metadata (dedupe to ensure one row per API)

df_well['API_NUMBER'] = df_well['API_WELL_NUMBER']
wmeta = (df_well.assign(API_WELL_NUMBER=df_well['API_WELL_NUMBER'].astype(str))
               .sort_values(['API_WELL_NUMBER'])
               .drop_duplicates('API_WELL_NUMBER', keep='first')
               .set_index('API_WELL_NUMBER')[['PLATFORM_ID','WELL_NAME', 'API_NUMBER']])



def meta(api, col):
    if api not in wmeta.index: return None
    val = wmeta.loc[api, col]
    if isinstance(val, pd.Series):
        val = val.iloc[0] if not val.empty else None
    return None if pd.isna(val) else str(val)

def slug(s, maxlen=120):
    if not s: return ""
    s = re.sub(r"[^A-Za-z0-9_.:-]+", "-", str(s))
    s = re.sub(r"-{2,}", "-", s).strip("-")
    return s[:maxlen]

# -----------------------------
# 3) TS naming & units (per-day)
# -----------------------------
UNIT_MAP = {
    'OIL_BBL_PER_DAY': 'bbl/day',
    'GAS_MCF_PER_DAY': 'Mcf/day',
    'WATER_BBL_PER_DAY': 'bbl/day',
    'CUMULATIVE_BOE_PER_DAY_TS': 'boe/day',       # no meter assigned to cumulative
}

UNIT_MAP2 = {
    'OIL_BBL_PER_DAY': 'volume_flow_rate:bbl_us-per-day',
    'GAS_MCF_PER_DAY': 'volume_flow_rate:mega-ft3-per-day',
    'WATER_BBL_PER_DAY': 'volume_flow_rate:bbl_us-per-day',
    'CUMULATIVE_BOE_PER_DAY_TS': 'volume_flow_rate:bbl_us-per-day',       # no meter assigned to cumulative
}

NAME_MAP = {
    'OIL_BBL_PER_DAY': 'Daily Oil Production',
    'GAS_MCF_PER_DAY': 'Daily Gas Production',
    'WATER_BBL_PER_DAY': 'Daily Water Production',
    'CUMULATIVE_BOE_PER_DAY_TS': 'Cumulative Daily Production',
}

# Map TS -> which fluid’s meter to use
TS_TO_FLUID = {
    'OIL_BBL_PER_DAY': 'oil',
    'GAS_MCF_PER_DAY': 'gas',
    'WATER_BBL_PER_DAY': 'water',
    'CUMULATIVE_BOE_PER_DAY_TS': None,   # explicitly no meter
}

# Map TS -> which fluid’s meter to use
TS_LOOKUP = {
    'OIL_BBL_PER_DAY': 'OIL_BBL_PER_DAY',
    'GAS_MCF_PER_DAY': 'GAS_MCF_PER_DAY',
    'WATER_BBL_PER_DAY': 'WATER_BBL_PER_DAY',
    'CUMULATIVE_BOE_PER_DAY_TS': 'CUMULATIVE_BOE_PER_DAY_TS'
}

# -----------------------------
# 4) Build the header table
# -----------------------------
header_rows = []

for api, rec in all_prod.items():
    platf = meta(api, 'PLATFORM_ID')
    well  = meta(api, 'WELL_NAME')
    wapi = meta(api, 'API_NUMBER')

    chosen = assignments.get(api, {'oil': None, 'gas': None, 'water': None})

    for ts_name, ts_val in rec.items():
        if ts_name == 'Production Data':
            wellboreId = str(rec['Production Data']['API Number'].iloc[0])
            continue

        # choose the meter for this TS (or None)
        fluid = TS_TO_FLUID.get(ts_name, None)
        meter_id = chosen.get(fluid) if fluid else None

        # uniqueId: ts + api [+ meter if present], never attach to cumulative
        parts = [ts_name, api]
        if meter_id is not None and not ts_name.startswith('CUMULATIVE'):
            parts.append(meter_id)
        unique_id = "_".join(slug(p) for p in parts)

        desc = f"{NAME_MAP.get(ts_name, ts_name)} time series for well {api}" + (f" ({well})" if well else "")

        tags = [ts_name.lower()]
        if well:  tags.append(well)
        if platf: tags.append(platf)

        header_rows.append({
            "uniqueId": unique_id,
            "name": NAME_MAP.get(ts_name, ts_name),
            "description": desc,
            "tags": tags,
            "aliases": [f"{ts_name}:{api}"] + ([f"{ts_name}:{api}:{meter_id}"] if meter_id else []),
            "sourceId": api,
            "sourceContext": "BSEE-Production_Data",
            "source": None,
            "sourceCreatedTime": None,
            "sourceUpdatedTime": None,
            "sourceCreatedUser": None,
            "sourceUpdatedUser": None,
            "isStep": False,
            "type": "DOUBLE",
            "sourceUnit": UNIT_MAP.get(ts_name, ""),
            # extras
            "platformId": platf,
            "wellName": well,
            "wellAPI": wapi,
            "meterId": meter_id,
            "cogUoM": UNIT_MAP2.get(ts_name, ""),
            "wellboreId": wellboreId,
            "tsLookup": TS_LOOKUP.get(ts_name, ""),
        })

header_table = pd.DataFrame(header_rows).drop_duplicates(subset=['uniqueId'])

# -----------------------------
# 5) (Optional) review violations
# -----------------------------
violations_df = (
    pd.DataFrame([(api, "; ".join(msgs)) for api, msgs in violations.items()],
                 columns=['API_WELL_NUMBER','violations'])
    if violations else pd.DataFrame(columns=['API_WELL_NUMBER','violations'])
)

print(f"Header rows: {len(header_table):,}")
print(f"Wells failing meter rule: {len(violations_df):,}")
print(f'{len(header_table[header_table["meterId"].notna()])} headers with a meterId')
print(f'{len(list(set(header_table["uniqueId"].tolist())))} out of {len(header_table)} uniqueIds are indeed unique...')
# display(violations_df.head())
header_table.head()
# Out:
# Header rows: 11,960
# Wells failing meter rule: 2,231
# 6094 headers with a meterId
# 11960 out of 11960 uniqueIds are indeed unique...
#                                             uniqueId  \
# 0  OIL_BBL_PER_DAY_6080740312_EQ_MET-20177183650-...
# 1  GAS_MCF_PER_DAY_6080740312_EQ_MET-3017718DS00-...
# 2  WATER_BBL_PER_DAY_6080740312_EQ_MET-2017718365...
# 3               CUMULATIVE_BOE_PER_DAY_TS_6080740312
# 4                         OIL_BBL_PER_DAY_6080440199
#
#                           name  \
# 0         Daily Oil Production
# 1         Daily Gas Production
# 2       Daily Water Production
# 3  Cumulative Daily Production
# 4         Daily Oil Production
#
#                                          description  \
# 0  Daily Oil Production time series for well 6080...
# 1  Daily Gas Production time series for well 6080...
# 2  Daily Water Production time series for well 60...
# 3  Cumulative Daily Production time series for we...
# 4  Daily Oil Production time series for well 6080...
#
#                                                 tags  \
# 0  [oil_bbl_per_day, LL004, PLTF-GB0388A (COOPE F...
# 1  [gas_mcf_per_day, LL004, PLTF-GB0388A (COOPE F...
# 2  [water_bbl_per_day, LL004, PLTF-GB0388A (COOPE...
# 3  [cumulative_boe_per_day_ts, LL004, PLTF-GB0388...
# 4       [oil_bbl_per_day,   001, PLTF-EB0165A-10297]
#
#                                              aliases    sourceId  \
# 0  [OIL_BBL_PER_DAY:6080740312, OIL_BBL_PER_DAY:6...  6080740312
# 1  [GAS_MCF_PER_DAY:6080740312, GAS_MCF_PER_DAY:6...  6080740312
# 2  [WATER_BBL_PER_DAY:6080740312, WATER_BBL_PER_D...  6080740312
# 3             [CUMULATIVE_BOE_PER_DAY_TS:6080740312]  6080740312
# 4                       [OIL_BBL_PER_DAY:6080440199]  6080440199
#
#           sourceContext source sourceCreatedTime sourceUpdatedTime  ...  \
# 0  BSEE-Production_Data   None              None              None  ...
# 1  BSEE-Production_Data   None              None              None  ...
# 2  BSEE-Production_Data   None              None              None  ...
# 3  BSEE-Production_Data   None              None              None  ...
# 4  BSEE-Production_Data   None              None              None  ...
#
#   isStep    type  sourceUnit                      platformId wellName  \
# 0  False  DOUBLE     bbl/day  PLTF-GB0388A (COOPE FPF)-24079    LL004
# 1  False  DOUBLE     Mcf/day  PLTF-GB0388A (COOPE FPF)-24079    LL004
# 2  False  DOUBLE     bbl/day  PLTF-GB0388A (COOPE FPF)-24079    LL004
# 3  False  DOUBLE     boe/day  PLTF-GB0388A (COOPE FPF)-24079    LL004
# 4  False  DOUBLE     bbl/day              PLTF-EB0165A-10297      001
#
#       wellAPI                      meterId                             cogUoM  \
# 0  6080740312  EQ_MET-20177183650-SL149844    volume_flow_rate:bbl_us-per-day
# 1  6080740312  EQ_MET-3017718DS00-A15HC080  volume_flow_rate:mega-ft3-per-day
# 2  6080740312  EQ_MET-20177183650-SL149845    volume_flow_rate:bbl_us-per-day
# 3  6080740312                         None    volume_flow_rate:bbl_us-per-day
# 4  6080440199                         None    volume_flow_rate:bbl_us-per-day
#
#      wellboreId                   tsLookup
# 0  608074031200            OIL_BBL_PER_DAY
# 1  608074031200            GAS_MCF_PER_DAY
# 2  608074031200          WATER_BBL_PER_DAY
# 3  608074031200  CUMULATIVE_BOE_PER_DAY_TS
# 4  608044019900            OIL_BBL_PER_DAY
#
# [5 rows x 22 columns]

# %% [markdown]
# #### Create TimeSeries Datapoints

# %%
from cognite.client.data_classes.data_modeling import NodeId

ts_space = 'dmu_rmdm_instances'

for i in range(len(header_table)):
    try:
        wapi = header_table['sourceId'].iloc[i]
        ts_extId = header_table['uniqueId'].iloc[i]
        ts = header_table['tsLookup'].iloc[i]
        dps = all_prod[wapi][ts]
        print(f"Iteration {i}: Upserting production data for well {wapi}")
        client.time_series.data.insert_multiple(
            [
                {"instance_id": NodeId(space=ts_space, external_id=ts_extId), "datapoints": dps}
            ]
        )
        print(f"Successfully upserted {len(dps)} datapoints in {ts_extId}")
    except CogniteAPIError as e:
        print(f"ℹ️  Somthing wrong for iteration '{i}' ({wapi} well).")
        raise
# Out:
# Iteration 0: Upserting production data for well 6080740312
# Successfully upserted 112 datapoints in OIL_BBL_PER_DAY_6080740312_EQ_MET-20177183650-SL149844
# Iteration 1: Upserting production data for well 6080740312
# Successfully upserted 112 datapoints in GAS_MCF_PER_DAY_6080740312_EQ_MET-3017718DS00-A15HC080
# Iteration 2: Upserting production data for well 6080740312
# Successfully upserted 112 datapoints in WATER_BBL_PER_DAY_6080740312_EQ_MET-20177183650-SL149845
# Iteration 3: Upserting production data for well 6080740312
# Successfully upserted 112 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6080
datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081140038
# Iteration 36: Upserting production data for well 6080740307
# Successfully upserted 98 datapoints in OIL_BBL_PER_DAY_6080740307
# Iteration 37: Upserting production data for well 6080740307
# Successfully upserted 98 datapoints in GAS_MCF_PER_DAY_6080740307
# Iteration 38: Upserting production data for well 6080740307
# Successfully upserted 98 datapoints in WATER_BBL_PER_DAY_6080740307
# Iteration 39: Upserting production data for well 6080740307
# Successfully upserted 98 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6080740307
# Iteration 40: Upserting production data for well 6081240031
# Successfully upserted 1 datapoints in OIL_BBL_PER_DAY_6081240031_EQ_MET-20608110254-800570
# Iteration 41: Upserting production data for well 6081240031
# Successfully upserted 1 datapoints in GAS_MCF_PER_DAY_6081240031_EQ_MET-3060811H004-AM2739544-1
# Iteration 42: Upserting production data for well 6081240031
# Successfully upserted 1 datapoints in WATER_BBL_PER_DAY_6081240031_EQ_MET-20608110254-901283
# Iteration 43: Upserting production data for well 6081240031
# Successfully upserted 1 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081240031
# Iteration 44: Upserting production data for well 6081741253
# Successfully upserted 1 datapoints in OIL_BBL_PER_DAY_6081741253_EQ_MET-2017710260M-LC42345
# Iteration 45: Upserting production data for well 6081741253
# Successfully upserted 1 datapoints in GAS_MCF_PER_DAY_6081741253_EQ_MET-3017710BB06-CW5147483006-A
# Iteration 46: Upserting production data for well 6081741253
# Successfully upserted 1 datapoints in WATER_BBL_PER_DAY_6081741253_EQ_MET-2017710260M-LE42678
# Iteration 47: Upserting production data for well 6081741253
# Successfully upserted 1 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081741253
# Iteration 48: Upserting production data for well 6081140381
# Successfully upserted 157 datapoints in OIL_BBL_PER_DAY_6081140381_EQ_MET-20177183651-WK152163
# Iteration 49: Upserting production data for well 6081140381
# Successfully upserted 157 datapoints in GAS_MCF_PER_DAY_6081140381_EQ_MET-3017718XE07-443823
# Iteration 50: Upserting production data for well 6081140381
# Successfully upserted 157 datapoints in WATER_BBL_PER_DAY_6081140381_EQ_MET-22177183653-1
# Iteration 51: Upserting production data for well 6081140381
# Successfully upserted 157 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081140381
# Iteration 52: Upserting production data for well 6081741143
# Successfully upserted 145 datapoints in OIL_BBL_PER_DAY_6081741143
# Iteration 53: Upserting production data for well 6081741143
# Successfully upserted 145 datapoints in GAS_MCF_PER_DAY_6081741143
# Iteration 54: Upserting production data for well 6081741143
# Successfully upserted 145 datapoints in WATER_BBL_PER_DAY_6081741143
# Iteration 55: Upserting production data for well 6081741143
# Successfully upserted 145 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081741143
# Iteration 56: Upserting production data for well 6081741193
# Successfully upserted 85 datapoints in OIL_BBL_PER_DAY_6081741193_EQ_MET-20608117000-100052451-9043397
# Iteration 57: Upserting production data for well 6081741193
# Successfully upserted 85 datapoints in GAS_MCF_PER_DAY_6081741193_EQ_MET-3060811MD00-A00FV056-A
# Iteration 58: Upserting production data for well 6081741193
# Successfully upserted 85 datapoints in WATER_BBL_PER_DAY_6081741193_EQ_MET-22608117000-1
# Iteration 59: Upserting production data for well 6081741193
# Successfully upserted 85 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081741193
# Iteration 60: Upserting production data for well 6080540056
# Successfully upserted 27 datapoints in OIL_BBL_PER_DAY_6080540056
# Iteration 61: Upserting production data for well 6080540056
# Successfully upserted 27 datapoints in GAS_MCF_PER_DAY_6080540056
# Iteration 62: Upserting production data for well 6080540056
# Successfully upserted 27 datapoints in WATER_BBL_PER_DAY_6080540056
# Iteration 63: Upserting production data for well 6080540056
# Successfully upserted 27 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6
# Successfully upserted 1 datapoints in GAS_MCF_PER_DAY_6081240080_EQ_MET-3060811H004-AM2739544-1
# Iteration 194: Upserting production data for well 6081240080
# Successfully upserted 1 datapoints in WATER_BBL_PER_DAY_6081240080_EQ_MET-20608110254-901283
# Iteration 195: Upserting production data for well 6081240080
# Successfully upserted 1 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081240080
# Iteration 196: Upserting production data for well 6081741390
# Successfully upserted 26 datapoints in OIL_BBL_PER_DAY_6081741390
# Iteration 197: Upserting production data for well 6081741390
# Successfully upserted 26 datapoints in GAS_MCF_PER_DAY_6081741390
# Iteration 198: Upserting production data for well 6081741390
# Successfully upserted 26 datapoints in WATER_BBL_PER_DAY_6081741390
# Iteration 199: Upserting production data for well 6081741390
# Successfully upserted 26 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081741390
# Iteration 200: Upserting production data for well 6081140135
# Successfully upserted 365 datapoints in OIL_BBL_PER_DAY_6081140135_EQ_MET-20171012500-42104
# Iteration 201: Upserting production data for well 6081140135
# Successfully upserted 365 datapoints in GAS_MCF_PER_DAY_6081140135
# Iteration 202: Upserting production data for well 6081140135
# Successfully upserted 365 datapoints in WATER_BBL_PER_DAY_6081140135_EQ_MET-20171012500-PJ147384
# Iteration 203: Upserting production data for well 6081140135
# Successfully upserted 365 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081140135
# Iteration 204: Upserting production data for well 6081741244
# Successfully upserted 89 datapoints in OIL_BBL_PER_DAY_6081741244_EQ_MET-20427110153-13913
# Iteration 205: Upserting production data for well 6081741244
# Successfully upserted 89 datapoints in GAS_MCF_PER_DAY_6081741244
# Iteration 206: Upserting production data for well 6081741244
# Successfully upserted 89 datapoints in WATER_BBL_PER_DAY_6081741244_EQ_MET-20427110153-13913-MTR
# Iteration 207: Upserting production data for well 6081741244
# Successfully upserted 89 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081741244
# Iteration 208: Upserting production data for well 6080740235
# Successfully upserted 169 datapoints in OIL_BBL_PER_DAY_6080740235_EQ_MET-20608112957-0153910
# Iteration 209: Upserting production data for well 6080740235
# Successfully upserted 169 datapoints in GAS_MCF_PER_DAY_6080740235_EQ_MET-3060811H007-188585-1
# Iteration 210: Upserting production data for well 6080740235
# Successfully upserted 169 datapoints in WATER_BBL_PER_DAY_6080740235_EQ_MET-2260811295G-1
# Iteration 211: Upserting production data for well 6080740235
# Successfully upserted 169 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6080740235
# Iteration 212: Upserting production data for well 6081640253
# Successfully upserted 248 datapoints in OIL_BBL_PER_DAY_6081640253_EQ_MET-2017710295N-0826101
# Iteration 213: Upserting production data for well 6081640253
# Successfully upserted 248 datapoints in GAS_MCF_PER_DAY_6081640253_EQ_MET-3017710BB0J-2010081202-01
# Iteration 214: Upserting production data for well 6081640253
# Successfully upserted 248 datapoints in WATER_BBL_PER_DAY_6081640253_EQ_MET-2017710295N-0826102
# Iteration 215: Upserting production data for well 6081640253
# Successfully upserted 248 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081640253
# Iteration 216: Upserting production data for well 6081740231
# Successfully upserted 399 datapoints in OIL_BBL_PER_DAY_6081740231_EQ_MET-20608110251-600819-9020886-9020887
# Iteration 217: Upserting production data for well 6081740231
# Successfully upserted 399 datapoints in GAS_MCF_PER_DAY_6081740231_EQ_MET-3060811H003-AM2739548-1
# Iteration 218: Upserting production data for well 6081740231
# Successfully upserted 399 datapoints in WATER_BBL_PER_DAY_6081740231_EQ_MET-20608110251-9023628
# Iteration 219: Upserting production data for well 6081740231
# Successfully upserted 399 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081740231
# Iteration 220: Upserting production data for well 6081741075
# Successfully upserted 98 datapoints in OIL_BBL_PER_DAY_6081741075
# Iteration 221: Upserting production data for well 6081741075
# Successfully upserted 98 datapoints in GAS_MCF_PER_DAY_6081741075
# Iteration 222: Upserting production data for well 6081741075
# Successfully upserted 98 datapoints in WATER_BBL_PER_DAY_6081741075
# Iteration 223: Upserting production data for well 6081741075
# Successfully upserted 98 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081741075
# Iteration 224: Upserting production data for well 6081741136
# Successfully upserted 136 datapoints in OIL_BBL_PER_DAY_6081741136
# Iteration 225: Upserting production data for well 6081741136
# Successfully upserted 136 datapoints in GAS_MCF_PER_DAY_6081741136
# Iteration 226: Upserting production data for well 6081741136
# Successfully upserted 136 datapoints in WATER_BBL_PER_DAY_6081741136
# Iteration 227: Upserting production data for well 6081741136
# Successfully upserted 136 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081741136
# Iteration 228: Upserting production data for well 6081740363
# Successfully upserted 2 datapoints in OIL_BBL_PER_DAY_6081740363_EQ_MET-20608117000-100052451-9043397
# Iteration 229: Upserting production data for well 6081740363
# Successfully upserted 2 datapoints in GAS_MCF_PER_DAY_6081740363_EQ_MET-3060811MD00-A00FV056-A
# Iteration 230: Upserting production data for well 6081740363
# Successfully upserted 2 datapoints in WATER_BBL_PER_DAY_6081740363_EQ_MET-22608117000-1
# Iteration 231: Upserting production data for well 6081740363
# Successfully upserted 2 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081740363
# Iteration 232: Upserting production data for well 6081150064
# Successfully upserted 5 datapoints in OIL_BBL_PER_DAY_6081150064_EQ_MET-20608050131-P637167
# Iteration 233: Upserting production data for well 6081150064
# Successfully upserted 5 datapoints in GAS_MCF_PER_DAY_6081150064_EQ_MET-3060805CC00-A07IV029-1
# Iteration 234: Upserting production data for well 6081150064
# Successfully upserted 5 datapoints in WATER_BBL_PER_DAY_6081150064_EQ_MET-22608050133-1
# Iteration 235: Upserting production data for well 6081150064
# Successfully upserted 5 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081150064
# Iteration 236: Upserting production data for well 6081740816
# Successfully upserted 2 datapoints in OIL_BBL_PER_DAY_6081740816
# Iteration 237: Upserting production data for well 6081740816
# Successfully upserted 2 datapoints in GAS_MCF_PER_DAY_6081740816
# Iteration 238: Upserting production data for well 6081740816
# Successfully upserted 2 datapoints in WATER_BBL_PER_DAY_6081740816
# Iteration 239: Upserting production data for well 6081740816
# Successfully upserted 2 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081740816
# Iteration 240: Upserting production data for well 6081140335
# Successfully upserted 1 datapoints in OIL_BBL_PER_DAY_6081140335_EQ_MET-20608110250-901068
# Iteration 241: Upserting production data for well 6081140335
# Successfully upserted 1 datapoints in GAS_MCF_PER_DAY_6081140335_EQ_MET-3060811H002-AM2739546-1
# Iteration 242: Upserting production data for well 6081140335
# Successfully upserted 1 datapoints in WATER_BBL_PER_DAY_6081140335_EQ_MET-22608110259-2
# Iteration 243: Upserting production data for well 6081140335
# Successfully upserted 1 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081140335
# Iteration 244: Upserting production data for well 6081140700
# Successfully upserted 28 datapoints in OIL_BBL_PER_DAY_6081140700
# Iteration 245: Upserting production data for well 6081140700
# Successfully upserted 28 datapoints in GAS_MCF_PER_DAY_6081140700_EQ_MET-3042708SA00-T160145211-01
# Iteration 246: Upserting production data for well 6081140700
# Successfully upserted 28 datapoints in WATER_BBL_PER_DAY_6081140700_EQ_MET-22427080510-1
# Iteration 247: Upserting production data for well 6081140700
# Successfully upserted 28 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081140700
# Iteration 248: Upserting production data for well 6080740203
# Successfully upserted 224 datapoints in OIL_BBL_PER_DAY_6080740203
# Iteration 249: Upserting production data for well 6080740203
# Successfully upserted 224 datapoints in GAS_MCF_PER_DAY_6080740203
# Iteration 250: Upserting production data for well 6080740203
# Successfully upserted 224 datapoints in WATER_BBL_PER_DAY_6080740203
# Iteration 251: Upserting production data for well 6080740203
# Successfully upserted 224 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6080740203
# Iteration 252: Upserting production data for well 6081140289
# Successfully upserted 99 datapoints in OIL_BBL_PER_DAY_6081140289_EQ_MET-20608174954-100053577
# Iteration 253: Upserting production data for well 6081140289
# Successfully upserted 99 datapoints in GAS_MCF_PER_DAY_6081140289_EQ_MET-3060817Z006-A16JB003-1
# Iteration 254: Upserting production data for well 6081140289
# Successfully upserted 99 datapoints in WATER_BBL_PER_DAY_6081140289_EQ_MET-22608174956-1
# Iteration 255: Upserting production data for well 6081140289
# Successfully upserted 99 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081140289
# Iteration 256: Upserting production data for well 6081741276
# Successfully upserted 1 datapoints in OIL_BBL_PER_DAY_6081741276
# Iteration 257: Upserting production data for well 6081741276
# Successfully upserted 1 datapoints in GAS_MCF_PER_DAY_6081741276
# Iteration 258: Upserting production data for well 6081741276
# Successfully upserted 1 datapoints in WATER_BBL_PER_DAY_6081741276
# Iteration 259: Upserting production data for well 6081741276
# Successfully upserted 1 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081741276
# Iteration 260: Upserting production data for well 6081040129
# Successfully upserted 53 datapoints in OIL_BBL_PER_DAY_6081040129
# Iteration 261: Upserting production data for well 6081040129
# Successfully upserted 53 datapoints in GAS_MCF_PER_DAY_6081040129
# Iteration 262: Upserting production data for well 6081040129
# Successfully upserted 53 datapoints in WATER_BBL_PER_DAY_6081040129
# Iteration 263: Upserting production data for well 6081040129
# Successfully upserted 53 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081040129
# Iteration 264: Upserting production data for well 6081740980
# Successfully upserted 1 datapoints in OIL_BBL_PER_DAY_6081740980
# Iteration 265: Upserting production data for well 6081740980
# Successfully upserted 1 datapoints in GAS_MCF_PER_DAY_6081740980
# Iteration 266: Upserting production data for well 6081740980
# Successfully upserted 1 datapoints in WATER_BBL_PER_DAY_6081740980
# Iteration 267: Upserting production data for well 6081740980
# Successfully upserted 1 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081740980
# Iteration 268: Upserting production data for well 6081741389
# Successfully upserted 29 datapoints in OIL_BBL_PER_DAY_6081741389_EQ_MET-2017710260M-LC42345
# Iteration 269: Upserting production data for well 6081741389
# Successfully upserted 29 datapoints in GAS_MCF_PER_DAY_6081741389_EQ_MET-3017710BB06-CW5147483006-A
# Iteration 270: Upserting production data for well 6081741389
# Successfully upserted 29 datapoints in WATER_BBL_PER_DAY_6081741389_EQ_MET-2017710260M-LE42678
# Iteration 271: Upserting production data for well 6081741389
# Successfully upserted 29 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081741389
# Iteration 272: Upserting production data for well 6081740871
# Successfully upserted 35 datapoints in OIL_BBL_PER_DAY_6081740871_EQ_MET-2060811295B-9010184
# Iteration 273: Upserting production data for well 6081740871
# Successfully upserted 35 datapoints in GAS_MCF_PER_DAY_6081740871
# Iteration 274: Upserting production data for well 6081740871
# Successfully upserted 35 datapoints in WATER_BBL_PER_DAY_6081740871_EQ_MET-2060811295B-9010186
# Iteration 275: Upserting production data for well 6081740871
# Successfully upserted 35 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081740871
# Iteration 276: Upserting production data for well 6081140722
# Successfully upserted 18 datapoints in OIL_BBL_PER_DAY_6081140722_EQ_MET-20608113652-448129
# Iteration 277: Upserting production data for well 6081140722
# Successfully upserted 18 datapoints in GAS_MCF_PER_DAY_6081140722_EQ_MET-3060811H001-A17DB047
# Iteration 278: Upserting production data for well 6081140722
# Successfully upserted 18 datapoints in WATER_BBL_PER_DAY_6081140722_EQ_MET-20608113652-900536
# Iteration 279: Upserting production data for well 6081140722
# Successfully upserted 18 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081140722
# Iteration 280: Upserting production data for well 6080740201
# Successfully upserted 262 datapoints in OIL_BBL_PER_DAY_6080740201_EQ_MET-20608112957-0153910
# Iteration 281: Upserting production data for well 6080740201
# Successfully upserted 262 datapoints in GAS_MCF_PER_DAY_6080740201_EQ_MET-3060811H007-188585-1
# Iteration 282: Upserting production data for well 6080740201
# Successfully upserted 262 datapoints in WATER_BBL_PER_DAY_6080740201_EQ_MET-2260811295G-1
# Iteration 283: Upserting production data for well 6080740201
# Successfully upserted 262 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6080740201
# Iteration 284: Upserting production data for well 6081640410
# Successfully upserted 140 datapoints in OIL_BBL_PER_DAY_6081640410_EQ_MET-21171132800-LB142905
# Iteration 285: Upserting production data for well 6081640410
# Successfully upserted 140 datapoints in GAS_MCF_PER_DAY_6081640410
# Iteration 286: Upserting production data for well 6081640410
# Successfully upserted 140 datapoints in WATER_BBL_PER_DAY_6081640410_EQ_MET-21171132800-LB142906
# Iteration 287: Upserting production data for well 6081640410
# Successfully upserted 140 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081640410
# Iteration 288: Upserting production data for well 6081640245
# Successfully upserted 230 datapoints in OIL_BBL_PER_DAY_6081640245_EQ_MET-2017710295N-0826101
# Iteration 289: Upserting production data for well 6081640245
# Successfully upserted 230 datapoints in GAS_MCF_PER_DAY_6081640245_EQ_MET-3017710BB0J-2010081202-01
# Iteration 290: Upserting production data for well 6081640245
# Successfully upserted 230 datapoints in WATER_BBL_PER_DAY_6081640245_EQ_MET-2017710295N-0826102
# Iteration 291: Upserting production data for well 6081640245
# Successfully upserted 230 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081640245
# Iteration 292: Upserting production data for well 6081040075
# Successfully upserted 24 datapoints in OIL_BBL_PER_DAY_6081040075_EQ_MET-20171012400-88381
# Iteration 293: Upserting production data for well 6081040075
# Successfully upserted 24 datapoints in GAS_MCF_PER_DAY_6081040075_EQ_MET-3017101XW01-465669
# Iteration 294: Upserting production data for well 6081040075
# Successfully upserted 24 datapoints in WATER_BBL_PER_DAY_6081040075_EQ_MET-20171012400-94755
# Iteration 295: Upserting production data for well 6081040075
# Successfully upserted 24 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081040075
# Iteration 296: Upserting production data for well 6081640156
# Successfully upserted 3 datapoints in OIL_BBL_PER_DAY_6081640156
# Iteration 297: Upserting production data for well 6081640156
# Successfully upserted 3 datapoints in GAS_MCF_PER_DAY_6081640156_EQ_MET-3017709BW0L-09-175543-01-002-A
# Iteration 298: Upserting production data for well 6081640156
# Successfully upserted 3 datapoints in WATER_BBL_PER_DAY_6081640156_EQ_MET-2217709280J-1
# Iteration 299: Upserting production data for well 6081640156
# Successfully upserted 3 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081640156
# Iteration 300: Upserting production data for well 6081140501
# Successfully upserted 163 datapoints in OIL_BBL_PER_DAY_6081140501
# Iteration 301: Upserting production data for well 6081140501
# Successfully upserted 163 datapoints in GAS_MCF_PER_DAY_6081140501
# Iteration 302: Upserting production data for well 6081140501
# Successfully upserted 163 datapoints in WATER_BBL_PER_DAY_6081140501_EQ_MET-22427080517-1
# Iteration 303: Upserting production data for well 6081140501
# Successfully upserted 163 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081140501
# Iteration 304: Upserting production data for well 6081740133
# Successfully upserted 316 datapoints in OIL_BBL_PER_DAY_6081740133
# Iteration 305: Upserting production data for well 6081740133
# Successfully upserted 316 datapoints in GAS_MCF_PER_DAY_6081740133
# Iteration 306: Upserting production data for well 6081740133
# Successfully upserted 316 datapoints in WATER_BBL_PER_DAY_6081740133_EQ_MET-2260817511Q-MC-208-SS001
# Iteration 307: Upserting production data for well 6081740133
# Successfully upserted 316 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081740133
# Iteration 308: Upserting production data for well 6081140149
# Successfully upserted 89 datapoints in OIL_BBL_PER_DAY_6081140149_EQ_MET-20608112955-UH151513
# Iteration 309: Upserting production data for well 6081140149
# Successfully upserted 89 datapoints in GAS_MCF_PER_DAY_6081140149_EQ_MET-3060811DS00-12415634104-1
# Iteration 310: Upserting production data for well 6081140149
# Successfully upserted 89 datapoints in WATER_BBL_PER_DAY_6081140149_EQ_MET-20608112955-UH151514
# Iteration 311: Upserting production data for well 6081140149
# Successfully upserted 89 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081140149
# Iteration 312: Upserting production data for well 6080840001
# Successfully upserted 5 datapoints in OIL_BBL_PER_DAY_6080840001_EQ_MET-20171132000-B
# Iteration 313: Upserting production data for well 6080840001
# Successfully upserted 5 datapoints in GAS_MCF_PER_DAY_6080840001_EQ_MET-3017113BB00-T141265968
# Iteration 314: Upserting production data for well 6080840001
# Successfully upserted 5 datapoints in WATER_BBL_PER_DAY_6080840001_EQ_MET-20171132000-JH4829
# Iteration 315: Upserting production data for well 6080840001
# Successfully upserted 5 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6080840001
# Iteration 316: Upserting production data for well 6080740631
# Successfully upserted 3 datapoints in OIL_BBL_PER_DAY_6080740631
# Iteration 317: Upserting production data for well 6080740631
# Successfully upserted 3 datapoints in GAS_MCF_PER_DAY_6080740631
# Iteration 318: Upserting production data for well 6080740631
# Successfully upserted 3 datapoints in WATER_BBL_PER_DAY_6080740631
# Iteration 319: Upserting production data for well 6080740631
# Successfully upserted 3 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6080740631
# Iteration 320: Upserting production data for well 6081150036
# Successfully upserted 107 datapoints in OIL_BBL_PER_DAY_6081150036
# Iteration 321: Upserting production data for well 6081150036
# Successfully upserted 107 datapoints in GAS_MCF_PER_DAY_6081150036_EQ_MET-3017717E005-T152630480-A
# Iteration 322: Upserting production data for well 6081150036
# Successfully upserted 107 datapoints in WATER_BBL_PER_DAY_6081150036
# Iteration 323: Upserting production data for well 6081150036
# Successfully upserted 107 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081150036
# Iteration 324: Upserting production data for well 6080740237
# Successfully upserted 231 datapoints in OIL_BBL_PER_DAY_6080740237_EQ_MET-20608174952-KJ142248
# Iteration 325: Upserting production data for well 6080740237
# Successfully upserted 231 datapoints in GAS_MCF_PER_DAY_6080740237_EQ_MET-3060817Z004-12315327729
# Iteration 326: Upserting production data for well 6080740237
# Successfully upserted 231 datapoints in WATER_BBL_PER_DAY_6080740237_EQ_MET-22608174951-3
# Iteration 327: Upserting production data for well 6080740237
# Successfully upserted 231 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6080740237
# Iteration 328: Upserting production data for well 6081741324
# Successfully upserted 60 datapoints in OIL_BBL_PER_DAY_6081741324_EQ_MET-20608072603-CE154263
# Iteration 329: Upserting production data for well 6081741324
# Successfully upserted 60 datapoints in GAS_MCF_PER_DAY_6081741324_EQ_MET-3060807MD03-A03EV044-1
# Iteration 330: Upserting production data for well 6081741324
# Successfully upserted 60 datapoints in WATER_BBL_PER_DAY_6081741324_EQ_MET-20608072603-P644652248
# Iteration 331: Upserting production data for well 6081741324
# Successfully upserted 60 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081741324
# Iteration 332: Upserting production data for well 6081140190
# Successfully upserted 2 datapoints in OIL_BBL_PER_DAY_6081140190_EQ_MET-20608050131-P637167
# Iteration 333: Upserting production data for well 6081140190
# Successfully upserted 2 datapoints in GAS_MCF_PER_DAY_6081140190_EQ_MET-3060805CC00-A07IV029-1
# Iteration 334: Upserting production data for well 6081140190
# Successfully upserted 2 datapoints in WATER_BBL_PER_DAY_6081140190_EQ_MET-22608050133-1
# Iteration 335: Upserting production data for well 6081140190
# Successfully upserted 2 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081140190
# Iteration 336: Upserting production data for well 6081140659
# Successfully upserted 60 datapoints in OIL_BBL_PER_DAY_6081140659_EQ_MET-2042709015J-RM148820
# Iteration 337: Upserting production data for well 6081140659
# ...
# Successfully upserted 25 datapoints in GAS_MCF_PER_DAY_6081140093_EQ_MET-3017709XE07-CW9803D005-1
# Iteration 11850: Upserting production data for well 6081140093
# Successfully upserted 25 datapoints in WATER_BBL_PER_DAY_6081140093_EQ_MET-22177092507-1
# Iteration 11851: Upserting production data for well 6081140093
# Successfully upserted 25 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081140093
# Iteration 11852: Upserting production data for well 6081140444
# Successfully upserted 163 datapoints in OIL_BBL_PER_DAY_6081140444
# Iteration 11853: Upserting production data for well 6081140444
# Successfully upserted 163 datapoints in GAS_MCF_PER_DAY_6081140444
# Iteration 11854: Upserting production data for well 6081140444
# Successfully upserted 163 datapoints in WATER_BBL_PER_DAY_6081140444_EQ_MET-22427080517-1
# Iteration 11855: Upserting production data for well 6081140444
# Successfully upserted 163 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081140444
# Iteration 11856: Upserting production data for well 6081740012
# Successfully upserted 2 datapoints in OIL_BBL_PER_DAY_6081740012
# Iteration 11857: Upserting production data for well 6081740012
# Successfully upserted 2 datapoints in GAS_MCF_PER_DAY_6081740012
# Iteration 11858: Upserting production data for well 6081740012
# Successfully upserted 2 datapoints in WATER_BBL_PER_DAY_6081740012_EQ_MET-2260817511Q-MC-208-SS001
# Iteration 11859: Upserting production data for well 6081740012
# Successfully upserted 2 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081740012
# Iteration 11860: Upserting production data for well 6081740206
# Successfully upserted 3 datapoints in OIL_BBL_PER_DAY_6081740206_EQ_MET-2017710260M-LC42345
# Iteration 11861: Upserting production data for well 6081740206
# Successfully upserted 3 datapoints in GAS_MCF_PER_DAY_6081740206_EQ_MET-3017710BB06-CW5147483006-A
# Iteration 11862: Upserting production data for well 6081740206
# Successfully upserted 3 datapoints in WATER_BBL_PER_DAY_6081740206_EQ_MET-2017710260M-LE42678
# Iteration 11863: Upserting production data for well 6081740206
# Successfully upserted 3 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081740206
# Iteration 11864: Upserting production data for well 6080540082
# Successfully upserted 33 datapoints in OIL_BBL_PER_DAY_6080540082
# Iteration 11865: Upserting production data for well 6080540082
# Successfully upserted 33 datapoints in GAS_MCF_PER_DAY_6080540082_EQ_MET-3017101X000-5092
# Iteration 11866: Upserting production data for well 6080540082
# Successfully upserted 33 datapoints in WATER_BBL_PER_DAY_6080540082
# Iteration 11867: Upserting production data for well 6080540082
# Successfully upserted 33 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6080540082
# Iteration 11868: Upserting production data for well 6080540077
# Successfully upserted 1 datapoints in OIL_BBL_PER_DAY_6080540077_EQ_MET-2017710260R-NB145324
# Iteration 11869: Upserting production data for well 6080540077
# Successfully upserted 1 datapoints in GAS_MCF_PER_DAY_6080540077_EQ_MET-3017710BB0K-2011101261-1
# Iteration 11870: Upserting production data for well 6080540077
# Successfully upserted 1 datapoints in WATER_BBL_PER_DAY_6080540077_EQ_MET-2017710260R-NB145325
# Iteration 11871: Upserting production data for well 6080540077
# Successfully upserted 1 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6080540077
# Iteration 11872: Upserting production data for well 6081741302
# Successfully upserted 1 datapoints in OIL_BBL_PER_DAY_6081741302_EQ_MET-20170230510-XB78307
# Iteration 11873: Upserting production data for well 6081741302
# Successfully upserted 1 datapoints in GAS_MCF_PER_DAY_6081741302_EQ_MET-3017023G000-T152630470
# Iteration 11874: Upserting production data for well 6081741302
# Successfully upserted 1 datapoints in WATER_BBL_PER_DAY_6081741302_EQ_MET-20170230510-XM85285
# Iteration 11875: Upserting production data for well 6081741302
# Successfully upserted 1 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081741302
# Iteration 11876: Upserting production data for well 6080840049
# Successfully upserted 1 datapoints in OIL_BBL_PER_DAY_6080840049_EQ_MET-20171132000-B
# Iteration 11877: Upserting production data for well 6080840049
# Successfully upserted 1 datapoints in GAS_MCF_PER_DAY_6080840049_EQ_MET-3017113BB00-T141265968
# Iteration 11878: Upserting production data for well 6080840049
# Successfully upserted 1 datapoints in WATER_BBL_PER_DAY_6080840049_EQ_MET-20171132000-JH4829
# Iteration 11879: Upserting production data for well 6080840049
# Successfully upserted 1 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6
# Successfully upserted 3 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6080740643
# Iteration 11908: Upserting production data for well 6081741388
# Successfully upserted 38 datapoints in OIL_BBL_PER_DAY_6081741388
# Iteration 11909: Upserting production data for well 6081741388
# Successfully upserted 38 datapoints in GAS_MCF_PER_DAY_6081741388_EQ_MET-3017109K000-A00IJ147-A
# Iteration 11910: Upserting production data for well 6081741388
# Successfully upserted 38 datapoints in WATER_BBL_PER_DAY_6081741388
# Iteration 11911: Upserting production data for well 6081741388
# Successfully upserted 38 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081741388
# Iteration 11912: Upserting production data for well 6080440094
# Successfully upserted 3 datapoints in OIL_BBL_PER_DAY_6080440094
# Iteration 11913: Upserting production data for well 6080440094
# Successfully upserted 3 datapoints in GAS_MCF_PER_DAY_6080440094
# Iteration 11914: Upserting production data for well 6080440094
# Successfully upserted 3 datapoints in WATER_BBL_PER_DAY_6080440094
# Iteration 11915: Upserting production data for well 6080440094
# Successfully upserted 3 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6080440094
# Iteration 11916: Upserting production data for well 6081240102
# Successfully upserted 48 datapoints in OIL_BBL_PER_DAY_6081240102_EQ_MET-20608072600-LB142753
# Iteration 11917: Upserting production data for well 6081240102
# Successfully upserted 48 datapoints in GAS_MCF_PER_DAY_6081240102_EQ_MET-3060807K003-AM2739583
# Iteration 11918: Upserting production data for well 6081240102
# Successfully upserted 48 datapoints in WATER_BBL_PER_DAY_6081240102_EQ_MET-20608072600-LB142754
# Iteration 11919: Upserting production data for well 6081240102
# Successfully upserted 48 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081240102
# Iteration 11920: Upserting production data for well 6081740298
# Successfully upserted 3 datapoints in OIL_BBL_PER_DAY_6081740298
# Iteration 11921: Upserting production data for well 6081740298
# Successfully upserted 3 datapoints in GAS_MCF_PER_DAY_6081740298_EQ_MET-3017726MPL3-T134751008
# Iteration 11922: Upserting production data for well 6081740298
# Successfully upserted 3 datapoints in WATER_BBL_PER_DAY_6081740298
# Iteration 11923: Upserting production data for well 6081740298
# Successfully upserted 3 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081740298
# Iteration 11924: Upserting production data for well 6080740185
# Successfully upserted 2 datapoints in OIL_BBL_PER_DAY_6080740185_EQ_MET-20608112957-0153910
# Iteration 11925: Upserting production data for well 6080740185
# Successfully upserted 2 datapoints in GAS_MCF_PER_DAY_6080740185_EQ_MET-3060811H007-188585-1
# Iteration 11926: Upserting production data for well 6080740185
# Successfully upserted 2 datapoints in WATER_BBL_PER_DAY_6080740185_EQ_MET-2260811295G-1
# Iteration 11927: Upserting production data for well 6080740185
# Successfully upserted 2 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6080740185
# Iteration 11928: Upserting production data for well 6080740079
# Successfully upserted 111 datapoints in OIL_BBL_PER_DAY_6080740079
# Iteration 11929: Upserting production data for well 6080740079
# Successfully upserted 111 datapoints in GAS_MCF_PER_DAY_6080740079
# Iteration 11930: Upserting production data for well 6080740079
# Successfully upserted 111 datapoints in WATER_BBL_PER_DAY_6080740079
# Iteration 11931: Upserting production data for well 6080740079
# Successfully upserted 111 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6080740079
# Iteration 11932: Upserting production data for well 6081741252
# Successfully upserted 97 datapoints in OIL_BBL_PER_DAY_6081741252
# Iteration 11933: Upserting production data for well 6081741252
# Successfully upserted 97 datapoints in GAS_MCF_PER_DAY_6081741252
# Iteration 11934: Upserting production data for well 6081741252
# Successfully upserted 97 datapoints in WATER_BBL_PER_DAY_6081741252
# Iteration 11935: Upserting production data for well 6081741252
# Successfully upserted 97 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081741252
# Iteration 11936: Upserting production data for well 6081640460
# Successfully upserted 53 datapoints in OIL_BBL_PER_DAY_6081640460_EQ_MET-21171132800-LB142905
# Iteration 11937: Upserting production data for well 6081640460
# Successfully upserted 53 datapoints in GAS_MCF_PER_DAY_6081640460
# Iteration 11938: Upserting production data for well 6081640460
# Successfully upserted 53 datapoints in WATER_BBL_PER_DAY_6081640460_EQ_MET-21171132800-LB142906
# Iteration 11939: Upserting production data for well 6081640460
# Successfully upserted 53 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081640460
# Iteration 11940: Upserting production data for well 6080440089
# Successfully upserted 40 datapoints in OIL_BBL_PER_DAY_6080440089_EQ_MET-20170573450-644653232
# Iteration 11941: Upserting production data for well 6080440089
# Successfully upserted 40 datapoints in GAS_MCF_PER_DAY_6080440089
# Iteration 11942: Upserting production data for well 6080440089
# Successfully upserted 40 datapoints in WATER_BBL_PER_DAY_6080440089_EQ_MET-20170573450-644653233
# Iteration 11943: Upserting production data for well 6080440089
# Successfully upserted 40 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6080440089
# Iteration 11944: Upserting production data for well 6081140257
# Successfully upserted 106 datapoints in OIL_BBL_PER_DAY_6081140257_EQ_MET-20171012500-42104
# Iteration 11945: Upserting production data for well 6081140257
# Successfully upserted 106 datapoints in GAS_MCF_PER_DAY_6081140257
# Iteration 11946: Upserting production data for well 6081140257
# Successfully upserted 106 datapoints in WATER_BBL_PER_DAY_6081140257_EQ_MET-20171012500-PJ147384
# Iteration 11947: Upserting production data for well 6081140257
# Successfully upserted 106 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6081140257
# Iteration 11948: Upserting production data for well 6080740226
# Successfully upserted 186 datapoints in OIL_BBL_PER_DAY_6080740226_EQ_MET-20608112957-0153910
# Iteration 11949: Upserting production data for well 6080740226
# Successfully upserted 186 datapoints in GAS_MCF_PER_DAY_6080740226_EQ_MET-3060811H007-188585-1
# Iteration 11950: Upserting production data for well 6080740226
# Successfully upserted 186 datapoints in WATER_BBL_PER_DAY_6080740226_EQ_MET-2260811295G-1
# Iteration 11951: Upserting production data for well 6080740226
# Successfully upserted 186 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6080740226
# Iteration 11952: Upserting production data for well 6080440054
# Successfully upserted 450 datapoints in OIL_BBL_PER_DAY_6080440054
# Iteration 11953: Upserting production data for well 6080440054
# Successfully upserted 450 datapoints in GAS_MCF_PER_DAY_6080440054
# Iteration 11954: Upserting production data for well 6080440054
# Successfully upserted 450 datapoints in WATER_BBL_PER_DAY_6080440054_EQ_MET-2260817511Z-MC-215-SS001-ODD-JOB
# Iteration 11955: Upserting production data for well 6080440054
# Successfully upserted 450 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6080440054
# Iteration 11956: Upserting production data for well 6080440206
# Successfully upserted 229 datapoints in OIL_BBL_PER_DAY_6080440206_EQ_MET-20608112958-BK154030
# Iteration 11957: Upserting production data for well 6080440206
# Successfully upserted 229 datapoints in GAS_MCF_PER_DAY_6080440206_EQ_MET-3060811DS02-A03HV060-1
# Iteration 11958: Upserting production data for well 6080440206
# Successfully upserted 229 datapoints in WATER_BBL_PER_DAY_6080440206_EQ_MET-20608112958-BK154031
# Iteration 11959: Upserting production data for well 6080440206
# Successfully upserted 229 datapoints in CUMULATIVE_BOE_PER_DAY_TS_6080440206
